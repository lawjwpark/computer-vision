# %%
import torch

# %%
torch.__version__
# Out:
# '1.3.1+cpu'

# %%
pip install mmcv-full
# Out:
# ...
#      |████████████████████████████████| 605 kB 5.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 250 kB 27.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61.7 MB 46 kB/s s eta 0:00:01     |█████████████████████           | 40.3 MB 31.8 MB/s eta 0:00:01     |██████████████████████          | 42.4 MB 41.9 MB/s eta 0:00:01     |█████████████████████████▍      | 48.9 MB 41.9 MB/s eta 0:00:01
# ...
#   Created wheel for mmcv-full: filename=mmcv_full-1.7.1-cp37-cp37m-linux_x86_64.whl size=30674591 sha256=2026048c96d89a2363f83622fffda238c7c340eba5460fb8a282a715498d7c26
#   Stored in directory: /root/.cache/pip/wheels/27/d5/67/e59eb8b14401d1ac087a8a03641951cb4e32d09a23c62b7265
# Successfully built mmcv-full
# ...
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
cd '/workspace/mmdet_study/mmdet_study'
# Out:
# /workspace/mmdet_study/mmdet_study

# %%
# !unzip mmcv_github.zip -d mmcv_github/
# Out:
# Archive:  mmcv_github.zip
#   inflating: mmcv_github/__init__.py
#    creating: mmcv_github/arraymisc/
#   inflating: mmcv_github/arraymisc/__init__.py
#   inflating: mmcv_github/arraymisc/quantization.py
#    creating: mmcv_github/cnn/
#   inflating: mmcv_github/cnn/__init__.py
#   inflating: mmcv_github/cnn/alexnet.py
#    creating: mmcv_github/cnn/bricks/
#   inflating: mmcv_github/cnn/bricks/__init__.py
#   inflating: mmcv_github/cnn/bricks/activation.py
#   inflating: mmcv_github/cnn/bricks/context_block.py
#   inflating: mmcv_github/cnn/bricks/conv.py
#   inflating: mmcv_github/cnn/bricks/conv2d_adaptive_padding.py
#   inflating: mmcv_github/cnn/bricks/conv_module.py
#   inflating: mmcv_github/cnn/bricks/conv_ws.py
#   inflating: mmcv_github/cnn/bricks/depthwise_separable_conv_module.py
#   inflating: mmcv_github/cnn/bricks/drop.py
#   inflating: mmcv_github/cnn/bricks/generalized_attention.py
#   inflating: mmcv_github/cnn/bricks/hsigmoid.py
# ...
